# %% [markdown]
# # Part 3, Topic 1: Large Hamming Weight Swings (MAIN)

# %% [markdown]
# ---
# NOTE: This lab references some (commercial) training material on [ChipWhisperer.io](https://www.ChipWhisperer.io). You can freely execute and use the lab per the open-source license (including using it in your own courses if you distribute similarly), but you must maintain notice about this source location. Consider joining our training course to enjoy the full experience.
#
# ---

# %% [markdown]
# **SUMMARY:** *In the previous part of the course, you saw that a microcontroller's power consumption changes based on what it's doing. In the case of a simple password check, this allowed us to see how many characters of the password we had correct, eventually resulting in the password being broken.*
#
# *That attack was based on different code execution paths showing up differently in power traces. In this next set of labs, we'll posit that, not only does different instructions affect power consumption, the data being manipulated in the microcontroller also affects power consumption.*
#
#
# **LEARNING OUTCOMES:**
#
# * Using a power measurement to 'validate' a possible device model.
# * Detecting the value of a single bit using power measurement.
# * Breaking AES using the classic DPA attack.

# %% [markdown]
# ## Prerequisites
#
# Hold up! Before you continue, check you've done the following tutorials:
#
# * ☑ Jupyter Notebook Intro (you should be OK with plotting & running blocks).
# * ☑ SCA101 Intro (you should have an idea of how to get hardware-specific versions running).
# * ☑ SCA101 Part 2 (you should understand how power consumption changes based on what code is being run)

# %% [markdown]
# ## Power Trace Gathering
#
# At this point you've got to insert code to perform the power trace capture. There are two options here:
# * Capture from physical device.
# * Read from a file.
#
# You get to choose your adventure - see the two notebooks with the same name of this, but called `(SIMULATED)` or `(HARDWARE)` to continue. Inside those notebooks you should get some code to copy into the following section, which will define the capture function.
#
# Be sure you get the `"✔️ OK to continue!"` print once you run the next cell, otherwise things will fail later on!

# %%
# always run this cell ! either for the hardware or simulated test
# %matplotlib notebook
import matplotlib.pylab as plt
import matplotlib.font_manager as font_manager

import numpy as np

# %% [markdown]
# ## [Hardware]

# %%
SCOPETYPE = 'CWNANO'
PLATFORM = 'CWNANO'
CRYPTO_TARGET = 'TINYAES128C'
SS_VER = 'SS_VER_2_1'

# %%
# %run "../../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd ../../../hardware/victims/firmware/simpleserial-aes
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# Building for platform CWNANO with CRYPTO_TARGET=TINYAES128C
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# Blank crypto options, building for AES128
# Building for platform CWNANO with CRYPTO_TARGET=TINYAES128C
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# Blank crypto options, building for AES128
# make[1]: '.dep' is up to date.
# Building for platform CWNANO with CRYPTO_TARGET=TINYAES128C
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# Blank crypto options, building for AES128
# arm-none-eabi-gcc.exe (GNU Arm Embedded Toolchain 10-2020-q4-major) 10.2.1 20201103 (release)
# Copyright (C) 2020 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# Assembling: .././hal/stm32f0/stm32f0_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m0 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWNANO/stm32f0_startup.lst -I.././simpleserial/ -I.././simpleserial/ -I.././hal -I.././hal/stm32f0 -I.././hal/stm32f0/CMSIS -I.././hal/stm32f0/CMSIS/core -I.././hal/stm32f0/CMSIS/device -I.././hal/stm32f0/Legacy -I.././crypto/ -I.././crypto/tiny-AES128-C .././hal/stm32f0/stm32f0_startup.S -o objdir-CWNANO/stm32f0_startup.o
# .
# Compiling:
#     .././crypto/aes-independant.c ...Done!
# .
# Compiling:
#     .././simpleserial/simpleserial.c ...Done!
# .
# Compiling:
#     .././hal/stm32f0_nano/stm32f0_hal_nano.c ...Done!
# .
# Compiling:
#     simpleserial-aes.c ...Done!
# .
# Compiling:
#     .././crypto/tiny-AES128-C/aes.c ...Done!
# .
# Compiling:
#     .././hal/stm32f0/stm32f0_hal_lowlevel.c ...Done!
# .
# LINKING:
#     simpleserial-aes-CWNANO.elf ...Done!
# .
# Creating load file for Flash: simpleserial-aes-CWNANO.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature simpleserial-aes-CWNANO.elf simpleserial-aes-CWNANO.bin
# .
# Creating load file for Flash: simpleserial-aes-CWNANO.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature simpleserial-aes-CWNANO.elf simpleserial-aes-CWNANO.hex
# .
# Creating Symbol Table: simpleserial-aes-CWNANO.sym
# arm-none-eabi-nm -n simpleserial-aes-CWNANO.elf > simpleserial-aes-CWNANO.sym
# .
# Creating load file for EEPROM: simpleserial-aes-CWNANO.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex simpleserial-aes-CWNANO.elf simpleserial-aes-CWNANO.eep || exit 0
# .
# Creating Extended Listing: simpleserial-aes-CWNANO.lss
# arm-none-eabi-objdump -h -S -z simpleserial-aes-CWNANO.elf > simpleserial-aes-CWNANO.lss
# Building for platform CWNANO with CRYPTO_TARGET=TINYAES128C
# SS_VER set to SS_VER_2_1
# SS_VER set to SS_VER_2_1
# Blank crypto options, building for AES128
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#    5324	    536	   1568	   7428	   1d04	simpleserial-aes-CWNANO.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CWNANO Built-in Target (STM32F030) with:
# + CRYPTO_TARGET = TINYAES128C
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "../../../hardware/victims/firmware/simpleserial-aes/simpleserial-aes-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F03xx4/03xx6
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 5859 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 5859 bytes

# %% [markdown]
# **My notes :** The code below capture the power traces on a TINYAES128C. It captures 100 energy traces (with 5000 samples each) while sending a series of simple messages (16 * Byte) to the target and stores the energy traces and the messages sent in separate arrays (trace_array ad textin_array).

# %%
from tqdm import tnrange # To see the progress
import time              # in time

ktp = cw.ktp.Basic()     # It creates a KTP object (Key-Text Pair) 
print(ktp)

trace_array = []
textin_array = []

key, text = ktp.next()   # when calling ktp.next the object returns the next key/text pair. By default the sequence is random/unique to each exec

target.set_key(key)

N = 100
for i in tnrange(N, desc='Capturing traces'):
    scope.arm()
    print('text[0] avant, ', text[0])
    print('text avant, ', text)
    
    # looking if the last bit is 1 or 0
    if text[0] & 0x01:
        text[0] = 0xFF
    else:
        text[0] = 0x00
    target.simpleserial_write('p', text)
    print(text, '\n')
    
    ret = scope.capture()
    if ret:
        print("Target timed out!")
        continue
    
    response = target.simpleserial_read('r', 16)
    
    trace_array.append(scope.get_last_trace())
    textin_array.append(text)
    
    key, text = ktp.next() 
    #print(ktp)
# Out:
# key: ['0x2b', '0x7e', '0x15', '0x16', '0x28', '0xae', '0xd2', '0xa6', '0xab', '0xf7', '0x15', '0x88', '0x9', '0xcf', '0x4f', '0x3c']
# text: ['0x0', '0x1', '0x2', '0x3', '0x4', '0x5', '0x6', '0x7', '0x8', '0x9', '0xa', '0xb', '0xc', '0xd', '0xe', '0xf']
# C:\Users\diogenem\AppData\Local\Temp\ipykernel_22324\4151264641.py:15: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   for i in tnrange(N, desc='Capturing traces'):
# Capturing traces:   0%|          | 0/100 [00:00<?, ?it/s]
# text[0] avant,  254
# text avant,  CWbytearray(b'fe 75 11 f9 b8 e4 12 f1 a4 5a 78 dc d6 85 f4 af')
# CWbytearray(b'00 75 11 f9 b8 e4 12 f1 a4 5a 78 dc d6 85 f4 af')
#
# text[0] avant,  197
# text avant,  CWbytearray(b'c5 30 54 a1 31 c9 ab 25 e0 89 5e 01 f2 69 d6 14')
# CWbytearray(b'ff 30 54 a1 31 c9 ab 25 e0 89 5e 01 f2 69 d6 14')
#
# text[0] avant,  40
# text avant,  CWbytearray(b'28 8d e2 a7 89 8b 51 9b 1c 6e 77 eb 62 40 52 14')
# CWbytearray(b'00 8d e2 a7 89 8b 51 9b 1c 6e 77 eb 62 40 52 14')
#
# text[0] avant,  66
# text avant,  CWbytearray(b'42 f7 6d e3 72 46 d1 7d 16 d6 09 a6 1f 4a 02 a2')
# CWbytearray(b'00 f7 6d e3 72 46 d1 7d 16 d6 09 a6 1f 4a 02 a2')
#
# text[0] avant,  145
# text avant,  CWbytearray(b'91 49 a3 af 1d 2e aa 20 21 af 2e d3 27 00 f8 a8')
# CWbytearray(b'ff 49 a3 af 1d 2e aa 20 21 af 2e d3 27 00 f8 a8')
#
# text[0] avant,  32
# text avant,  CWbytearray(b'20 ab be ea e4 0c 3e 00 31 44 78 b0 68 eb fe f0')
# CWbytearray(b'00 ab be ea e4 0c 3e 00 31 44 78 b0 68 eb fe f0')
#
# text[0] avant,  159
# text avant,  CWbytearray(b'9f 54 75 34 39 98 2f b8 e1 e3 72 3e eb e3 87 ab')
# CWbytearray(b'ff 54 75 34 39 98 2f b8 e1 e3 72 3e eb e3 87 ab')
#
# text[0] avant,  166
# text avant,  CWbytearray(b'a6 d6 c9 0f 8e 10 d5 44 d7 67 34 ad 08 a7 a8 6d')
# CWbytearray(b'00 d6 c9 0f 8e 10 d5 44 d7 67 34 ad 08 a7 a8 6d')
#
# text[0] avant,  221
# text avant,  CWbytearray(b'dd ee 06 8f 1c 6f a1 c9 30 49 42 a6 46 ef 1f b6')
# CWbytearray(b'ff ee 06 8f 1c 6f a1 c9 30 49 42 a6 46 ef 1f b6')
#
# text[0] avant,  132
# text avant,  CWbytearray(b'84 d0 74 3e af fa f5 5b 0a bf 3c b8 0e d2 80 2b')
# CWbytearray(b'00 d0 74 3e af fa f5 5b 0a bf 3c b8 0e d2 80 2b')
#
# text[0] avant,  140
# text avant,  CWbytearray(b'8c e8 3e ae 0b 89 ba da 2b 0a fe d8 e0 f3 94 a6')
# CWbytearray(b'00 e8 3e ae 0b 89 ba da 2b 0a fe d8 e0 f3 94 a6')
#
# text[0] avant,  80
# text avant,  CWbytearray(b'50 57 aa e7 c5 a3 e1 ed d1 46 46 4a ec 70 6b 51')
# CWbytearray(b'00 57 aa e7 c5 a3 e1 ed d1 46 46 4a ec 70 6b 51')
#
# text[0] avant,  229
# text avant,  CWbytearray(b'e5 89 47 f7 79 ce 11 e9 03 d7 34 3c 29 ec e9 ce')
# CWbytearray(b'ff 89 47 f7 79 ce 11 e9 03 d7 34 3c 29 ec e9 ce')
#
# text[0] avant,  122
# text avant,  CWbytearray(b'7a c6 94 71 fc a4 84 db af b3 7e a0 c7 7e 07 ef')
# CWbytearray(b'00 c6 94 71 fc a4 84 db af b3 7e a0 c7 7e 07 ef')
#
# text[0] avant,  23
# text avant,  CWbytearray(b'17 f1 65 1c 8e 90 72 d9 db c3 78 47 80 8a 42 e4')
# CWbytearray(b'ff f1 65 1c 8e 90 72 d9 db c3 78 47 80 8a 42 e4')
#
# text[0] avant,  163
# text avant,  CWbytearray(b'a3 51 5a 5a 15 46 0d 6f e3 12 cc c3 35 8e 22 65')
# CWbytearray(b'ff 51 5a 5a 15 46 0d 6f e3 12 cc c3 35 8e 22 65')
#
# text[0] avant,  109
# text avant,  CWbytearray(b'6d 76 6c 35 fc cb 11 b7 85 7a 0e f2 06 26 15 bf')
# CWbytearray(b'ff 76 6c 35 fc cb 11 b7 85 7a 0e f2 06 26 15 bf')
#
# text[0] avant,  7
# text avant,  CWbytearray(b'07 20 bf 8e 84 76 d6 b7 5d 4b 66 db bf d5 3f 83')
# CWbytearray(b'ff 20 bf 8e 84 76 d6 b7 5d 4b 66 db bf d5 3f 83')
#
# text[0] avant,  237
# text avant,  CWbytearray(b'ed e5 3c 2a ee 60 98 6f 0a 6a 74 81 06 09 6b c4')
# CWbytearray(b'ff e5 3c 2a ee 60 98 6f 0a 6a 74 81 06 09 6b c4')
#
# text[0] avant,  11
# text avant,  CWbytearray(b'0b 5d 7a 91 e6 7b 8b 3d bf f1 64 35 da c8 7b 4f')
# CWbytearray(b'ff 5d 7a 91 e6 7b 8b 3d bf f1 64 35 da c8 7b 4f')
#
# text[0] avant,  205
# text avant,  CWbytearray(b'cd 52 61 b8 c4 a7 45 5f 28 66 0b ee 16 46 b5 ca')
# CWbytearray(b'ff 52 61 b8 c4 a7 45 5f 28 66 0b ee 16 46 b5 ca')
#
# text[0] avant,  245
# text avant,  CWbytearray(b'f5 4b f1 d8 fe ca 8f 09 49 50 b7 51 fb 82 f4 79')
# CWbytearray(b'ff 4b f1 d8 fe ca 8f 09 49 50 b7 51 fb 82 f4 79')
#
# text[0] avant,  237
# text avant,  CWbytearray(b'ed 68 b1 4f be e7 d9 28 2a 08 94 a7 d7 22 5e f5')
# CWbytearray(b'ff 68 b1 4f be e7 d9 28 2a 08 94 a7 d7 22 5e f5')
#
# text[0] avant,  133
# text avant,  CWbytearray(b'85 55 cc dc 81 07 b1 4e 69 35 81 70 33 c3 7c f9')
# CWbytearray(b'ff 55 cc dc 81 07 b1 4e 69 35 81 70 33 c3 7c f9')
#
# text[0] avant,  92
# text avant,  CWbytearray(b'5c d1 fa 34 8e 15 bb 23 11 2a 0a b3 b9 9d 98 e0')
# CWbytearray(b'00 d1 fa 34 8e 15 bb 23 11 2a 0a b3 b9 9d 98 e0')
#
# text[0] avant,  46
# text avant,  CWbytearray(b'2e b2 d6 39 2c 94 c6 5a a0 08 d6 1a 9c bb 3d fd')
# CWbytearray(b'00 b2 d6 39 2c 94 c6 5a a0 08 d6 1a 9c bb 3d fd')
#
# text[0] avant,  246
# text avant,  CWbytearray(b'f6 68 aa f4 25 1e 72 f8 fe ea 65 e0 ac f2 34 5e')
# CWbytearray(b'00 68 aa f4 25 1e 72 f8 fe ea 65 e0 ac f2 34 5e')
#
# text[0] avant,  19
# text avant,  CWbytearray(b'13 36 e3 c1 39 34 93 f0 c3 61 41 a3 9e 50 5b 38')
# CWbytearray(b'ff 36 e3 c1 39 34 93 f0 c3 61 41 a3 9e 50 5b 38')
#
# text[0] avant,  15
# text avant,  CWbytearray(b'0f dc 5a 99 70 12 f7 da 32 97 c7 e0 bd 90 40 b8')
# CWbytearray(b'ff dc 5a 99 70 12 f7 da 32 97 c7 e0 bd 90 40 b8')
#
# text[0] avant,  136
# text avant,  CWbytearray(b'88 31 db 41 a6 0e 09 b7 b6 da eb 36 81 a2 e9 71')
# CWbytearray(b'00 31 db 41 a6 0e 09 b7 b6 da eb 36 81 a2 e9 71')
#
# text[0] avant,  57
# text avant,  CWbytearray(b'39 cb 38 51 22 c4 9f 12 7d 72 22 f9 f3 f4 7f a1')
# CWbytearray(b'ff cb 38 51 22 c4 9f 12 7d 72 22 f9 f3 f4 7f a1')
#
# text[0] avant,  166
# text avant,  CWbytearray(b'a6 00 55 f4 1a 1b 3a cf e8 34 4d 59 65 0f cb 50')
# CWbytearray(b'00 00 55 f4 1a 1b 3a cf e8 34 4d 59 65 0f cb 50')
#
# text[0] avant,  138
# text avant,  CWbytearray(b'8a 32 e9 08 c5 51 13 a4 99 2d 64 9f d1 f8 df 41')
# CWbytearray(b'00 32 e9 08 c5 51 13 a4 99 2d 64 9f d1 f8 df 41')
#
# text[0] avant,  54
# text avant,  CWbytearray(b'36 15 9c f4 78 5d 27 81 f2 97 9e 14 b9 e0 59 cb')
# CWbytearray(b'00 15 9c f4 78 5d 27 81 f2 97 9e 14 b9 e0 59 cb')
#
# text[0] avant,  76
# text avant,  CWbytearray(b'4c 95 59 35 6b 07 77 0f 4a 47 7f d1 7a fc 3e 68')
# CWbytearray(b'00 95 59 35 6b 07 77 0f 4a 47 7f d1 7a fc 3e 68')
#
# text[0] avant,  218
# text avant,  CWbytearray(b'da 1c 0d be 44 18 1b d1 77 6a e6 0f 70 52 a6 f8')
# CWbytearray(b'00 1c 0d be 44 18 1b d1 77 6a e6 0f 70 52 a6 f8')
#
# text[0] avant,  20
# text avant,  CWbytearray(b'14 01 bd 18 d5 67 df c5 d2 da 0c e6 59 20 12 df')
# CWbytearray(b'00 01 bd 18 d5 67 df c5 d2 da 0c e6 59 20 12 df')
#
# text[0] avant,  250
# text avant,  CWbytearray(b'fa 5a b6 39 f4 f0 93 35 0b 94 e7 e2 b1 1c 00 9f')
# CWbytearray(b'00 5a b6 39 f4 f0 93 35 0b 94 e7 e2 b1 1c 00 9f')
#
# text[0] avant,  200
# text avant,  CWbytearray(b'c8 0f c3 26 8c 58 e6 37 be ad 9b b5 22 31 17 69')
# CWbytearray(b'00 0f c3 26 8c 58 e6 37 be ad 9b b5 22 31 17 69')
#
# text[0] avant,  231
# text avant,  CWbytearray(b'e7 b7 fa b5 9f 20 14 84 c2 db ec 41 c1 3b 6f 9f')
# CWbytearray(b'ff b7 fa b5 9f 20 14 84 c2 db ec 41 c1 3b 6f 9f')
#
# text[0] avant,  247
# text avant,  CWbytearray(b'f7 ee 69 63 0e 84 99 b6 a5 84 e5 05 0c 82 59 7b')
# CWbytearray(b'ff ee 69 63 0e 84 99 b6 a5 84 e5 05 0c 82 59 7b')
#
# text[0] avant,  59
# text avant,  CWbytearray(b'3b 3f 5b 5e 28 e9 7d a8 c2 cf 25 53 72 91 1b cb')
# CWbytearray(b'ff 3f 5b 5e 28 e9 7d a8 c2 cf 25 53 72 91 1b cb')
#
# text[0] avant,  185
# text avant,  CWbytearray(b'b9 a9 c6 0b 24 40 79 a6 e8 00 95 96 6a 05 57 97')
# CWbytearray(b'ff a9 c6 0b 24 40 79 a6 e8 00 95 96 6a 05 57 97')
#
# text[0] avant,  180
# text avant,  CWbytearray(b'b4 7a 58 a3 aa 3e d9 46 7b a6 e2 c6 f2 82 a5 83')
# CWbytearray(b'00 7a 58 a3 aa 3e d9 46 7b a6 e2 c6 f2 82 a5 83')
#
# text[0] avant,  116
# text avant,  CWbytearray(b'74 f1 a1 e6 f1 28 ee 5c 42 fc 54 dc bc 93 f7 3a')
# CWbytearray(b'00 f1 a1 e6 f1 28 ee 5c 42 fc 54 dc bc 93 f7 3a')
#
# text[0] avant,  185
# text avant,  CWbytearray(b'b9 9f 7e 37 c1 5d 5a b3 13 16 3d 40 e1 06 8d 9b')
# CWbytearray(b'ff 9f 7e 37 c1 5d 5a b3 13 16 3d 40 e1 06 8d 9b')
#
# text[0] avant,  215
# text avant,  CWbytearray(b'd7 4d a2 3e 45 ed c2 1a 42 f9 de 3a d1 36 02 ff')
# CWbytearray(b'ff 4d a2 3e 45 ed c2 1a 42 f9 de 3a d1 36 02 ff')
#
# text[0] avant,  7
# text avant,  CWbytearray(b'07 58 6f 09 6d 3e a2 35 af 8d c8 8f 34 24 1f a4')
# CWbytearray(b'ff 58 6f 09 6d 3e a2 35 af 8d c8 8f 34 24 1f a4')
#
# text[0] avant,  114
# text avant,  CWbytearray(b'72 58 88 19 0e 00 a4 d6 b9 7a a4 1f 2d e0 bf 40')
# CWbytearray(b'00 58 88 19 0e 00 a4 d6 b9 7a a4 1f 2d e0 bf 40')
#
# text[0] avant,  238
# text avant,  CWbytearray(b'ee 82 f8 96 c6 c9 ca 07 e5 de 94 29 6c 38 38 a7')
# CWbytearray(b'00 82 f8 96 c6 c9 ca 07 e5 de 94 29 6c 38 38 a7')
#
# text[0] avant,  8
# text avant,  CWbytearray(b'08 ee 6b 78 eb ca d3 94 f7 0f 21 51 e0 70 ba 68')
# CWbytearray(b'00 ee 6b 78 eb ca d3 94 f7 0f 21 51 e0 70 ba 68')
# text[0] avant,  37
# text avant,  CWbytearray(b'25 54 e6 53 fc dc 43 8e de 6b 49 54 5b 5b 62 2e')
# CWbytearray(b'ff 54 e6 53 fc dc 43 8e de 6b 49 54 5b 5b 62 2e')
#
# text[0] avant,  175
# text avant,  CWbytearray(b'af 46 32 d3 84 d1 76 8b 65 67 d8 34 43 ea 59 fc')
# CWbytearray(b'ff 46 32 d3 84 d1 76 8b 65 67 d8 34 43 ea 59 fc')
#
# text[0] avant,  138
# text avant,  CWbytearray(b'8a b0 17 4f 5b 1e cf 4f f9 ab f4 98 14 38 01 14')
# CWbytearray(b'00 b0 17 4f 5b 1e cf 4f f9 ab f4 98 14 38 01 14')
#
# text[0] avant,  63
# text avant,  CWbytearray(b'3f b5 b2 25 13 89 35 ed 16 cf 39 a5 af 5a c4 cc')
# CWbytearray(b'ff b5 b2 25 13 89 35 ed 16 cf 39 a5 af 5a c4 cc')
#
# text[0] avant,  205
# text avant,  CWbytearray(b'cd 77 5f bc 43 7b 14 b0 d7 7e 80 fc f4 5f 2e 70')
# CWbytearray(b'ff 77 5f bc 43 7b 14 b0 d7 7e 80 fc f4 5f 2e 70')
#
# text[0] avant,  43
# text avant,  CWbytearray(b'2b 80 f2 b7 17 2c f9 23 bc a1 90 de ca 29 ea 0f')
# CWbytearray(b'ff 80 f2 b7 17 2c f9 23 bc a1 90 de ca 29 ea 0f')
#
# text[0] avant,  90
# text avant,  CWbytearray(b'5a 98 76 fb 95 c7 97 66 b5 2e c6 3c a6 6d c1 98')
# CWbytearray(b'00 98 76 fb 95 c7 97 66 b5 2e c6 3c a6 6d c1 98')
#
# text[0] avant,  158
# text avant,  CWbytearray(b'9e 5b f0 0f 5e 20 2d 24 f9 91 bf 05 0c 8e 90 92')
# CWbytearray(b'00 5b f0 0f 5e 20 2d 24 f9 91 bf 05 0c 8e 90 92')
#
# text[0] avant,  198
# text avant,  CWbytearray(b'c6 39 2a 71 b9 a0 cf 7b d9 be 05 1f 7d 69 df 15')
# CWbytearray(b'00 39 2a 71 b9 a0 cf 7b d9 be 05 1f 7d 69 df 15')
#
# text[0] avant,  152
# text avant,  CWbytearray(b'98 ba 30 54 8a 16 0a ec a9 0f 17 06 51 ed e2 9e')
# CWbytearray(b'00 ba 30 54 8a 16 0a ec a9 0f 17 06 51 ed e2 9e')
#
# text[0] avant,  210
# text avant,  CWbytearray(b'd2 94 86 71 05 f9 8c 25 8d 6d b6 f2 df 30 ff 21')
# CWbytearray(b'00 94 86 71 05 f9 8c 25 8d 6d b6 f2 df 30 ff 21')
#
# text[0] avant,  221
# text avant,  CWbytearray(b'dd 72 de bf 3f b9 4c ad 10 1f 37 39 38 b8 69 35')
# CWbytearray(b'ff 72 de bf 3f b9 4c ad 10 1f 37 39 38 b8 69 35')
#
# text[0] avant,  140
# text avant,  CWbytearray(b'8c f7 ea 73 21 fa 7a 7a af f5 74 52 2d 22 58 a8')
# CWbytearray(b'00 f7 ea 73 21 fa 7a 7a af f5 74 52 2d 22 58 a8')
#
# text[0] avant,  10
# text avant,  CWbytearray(b'0a 34 d6 c3 db d7 72 c9 db 30 5d 02 35 6c ef d9')
# CWbytearray(b'00 34 d6 c3 db d7 72 c9 db 30 5d 02 35 6c ef d9')
#
# text[0] avant,  221
# text avant,  CWbytearray(b'dd da 79 2a 0f 64 31 4f 82 ff 42 6e 00 d3 54 11')
# CWbytearray(b'ff da 79 2a 0f 64 31 4f 82 ff 42 6e 00 d3 54 11')
#
# text[0] avant,  44
# text avant,  CWbytearray(b'2c 50 10 ec a8 1b 9f 56 37 3f 5d 01 74 8a 3f 27')
# CWbytearray(b'00 50 10 ec a8 1b 9f 56 37 3f 5d 01 74 8a 3f 27')
#
# text[0] avant,  101
# text avant,  CWbytearray(b'65 43 b5 01 cd 52 fc c8 17 89 01 87 b8 d6 63 46')
# CWbytearray(b'ff 43 b5 01 cd 52 fc c8 17 89 01 87 b8 d6 63 46')
#
# text[0] avant,  160
# text avant,  CWbytearray(b'a0 bb 0d 0d 19 07 d6 43 5e f9 4c a1 0e 71 28 54')
# CWbytearray(b'00 bb 0d 0d 19 07 d6 43 5e f9 4c a1 0e 71 28 54')
#
# text[0] avant,  252
# text avant,  CWbytearray(b'fc 5a 4e f3 ec 7e f9 73 59 f4 51 e4 c0 00 92 14')
# CWbytearray(b'00 5a 4e f3 ec 7e f9 73 59 f4 51 e4 c0 00 92 14')
#
# text[0] avant,  138
# text avant,  CWbytearray(b'8a 79 0e 54 33 17 44 8b d3 66 34 d4 f7 9e fc d0')
# CWbytearray(b'00 79 0e 54 33 17 44 8b d3 66 34 d4 f7 9e fc d0')
#
# text[0] avant,  91
# text avant,  CWbytearray(b'5b 3f ad 56 61 64 88 a8 a0 83 f1 62 53 30 c7 84')
# CWbytearray(b'ff 3f ad 56 61 64 88 a8 a0 83 f1 62 53 30 c7 84')
#
# text[0] avant,  148
# text avant,  CWbytearray(b'94 18 53 da d2 70 0f a2 a4 f7 47 88 2d 7b e5 97')
# CWbytearray(b'00 18 53 da d2 70 0f a2 a4 f7 47 88 2d 7b e5 97')
#
# text[0] avant,  138
# text avant,  CWbytearray(b'8a fe b7 6c ea 87 b2 d0 a9 71 55 7d 59 d4 95 af')
# CWbytearray(b'00 fe b7 6c ea 87 b2 d0 a9 71 55 7d 59 d4 95 af')
#
# text[0] avant,  236
# text avant,  CWbytearray(b'ec 2b 3e 6b 9a 7a 32 2b 17 62 2a 1c 01 77 92 be')
# CWbytearray(b'00 2b 3e 6b 9a 7a 32 2b 17 62 2a 1c 01 77 92 be')
#
# text[0] avant,  131
# text avant,  CWbytearray(b'83 c4 71 9f f5 7e be 2e 3c 47 ee b1 bd d1 9c cb')
# CWbytearray(b'ff c4 71 9f f5 7e be 2e 3c 47 ee b1 bd d1 9c cb')
#
# text[0] avant,  102
# text avant,  CWbytearray(b'66 ae 0d ba fd 3b 73 5a 77 92 f2 e6 b8 e7 80 f8')
# CWbytearray(b'00 ae 0d ba fd 3b 73 5a 77 92 f2 e6 b8 e7 80 f8')
#
# text[0] avant,  207
# text avant,  CWbytearray(b'cf ab 4f 2c 58 b9 3f 81 b1 5b 53 0e f7 58 8a 44')
# CWbytearray(b'ff ab 4f 2c 58 b9 3f 81 b1 5b 53 0e f7 58 8a 44')
#
# text[0] avant,  86
# text avant,  CWbytearray(b'56 b0 88 af 54 d9 c0 82 13 3a e8 1c be fa 84 c8')
# CWbytearray(b'00 b0 88 af 54 d9 c0 82 13 3a e8 1c be fa 84 c8')
#
# text[0] avant,  131
# text avant,  CWbytearray(b'83 3d 7b a4 33 5b 78 fa b5 e6 21 a8 8a 82 74 ab')
# CWbytearray(b'ff 3d 7b a4 33 5b 78 fa b5 e6 21 a8 8a 82 74 ab')
#
# text[0] avant,  74
# text avant,  CWbytearray(b'4a 85 d2 e7 68 ef 9b 78 b7 bd b7 e1 df e0 51 39')
# CWbytearray(b'00 85 d2 e7 68 ef 9b 78 b7 bd b7 e1 df e0 51 39')
#
# text[0] avant,  36
# text avant,  CWbytearray(b'24 37 a4 3c e2 03 a0 d7 95 df ff 06 ea e2 b6 b9')
# CWbytearray(b'00 37 a4 3c e2 03 a0 d7 95 df ff 06 ea e2 b6 b9')
#
# text[0] avant,  217
# text avant,  CWbytearray(b'd9 1b 64 b5 33 c0 98 aa 2e fc de 51 13 4e 2f 35')
# CWbytearray(b'ff 1b 64 b5 33 c0 98 aa 2e fc de 51 13 4e 2f 35')
#
# text[0] avant,  249
# text avant,  CWbytearray(b'f9 90 c2 2f 9f 88 39 41 90 04 0b d2 f1 07 a6 e9')
# CWbytearray(b'ff 90 c2 2f 9f 88 39 41 90 04 0b d2 f1 07 a6 e9')
#
# text[0] avant,  0
# text avant,  CWbytearray(b'00 8e 3f b3 ac 14 09 c1 a5 d2 35 71 f4 61 e8 47')
# CWbytearray(b'00 8e 3f b3 ac 14 09 c1 a5 d2 35 71 f4 61 e8 47')
#
# text[0] avant,  245
# text avant,  CWbytearray(b'f5 d5 6a 41 8e 3d de 6c a5 09 c3 8c a5 30 45 f4')
# CWbytearray(b'ff d5 6a 41 8e 3d de 6c a5 09 c3 8c a5 30 45 f4')
#
# text[0] avant,  237
# text avant,  CWbytearray(b'ed df fc 30 a8 87 c0 a6 97 3b 35 55 74 3b e0 48')
# CWbytearray(b'ff df fc 30 a8 87 c0 a6 97 3b 35 55 74 3b e0 48')
#
# text[0] avant,  210
# text avant,  CWbytearray(b'd2 26 ff 02 a3 2d ce 71 b4 5b 0f 16 37 b3 01 2d')
# CWbytearray(b'00 26 ff 02 a3 2d ce 71 b4 5b 0f 16 37 b3 01 2d')
#
# text[0] avant,  23
# text avant,  CWbytearray(b'17 cf b3 d9 18 a8 36 e3 9b fe 67 a9 97 84 c8 90')
# CWbytearray(b'ff cf b3 d9 18 a8 36 e3 9b fe 67 a9 97 84 c8 90')
#
# text[0] avant,  234
# text avant,  CWbytearray(b'ea b2 91 ad 49 1c 61 35 65 5b 2d 61 96 61 2f 21')
# CWbytearray(b'00 b2 91 ad 49 1c 61 35 65 5b 2d 61 96 61 2f 21')
#
# text[0] avant,  45
# text avant,  CWbytearray(b'2d 39 e8 51 2d 1f 64 2e 55 af 1f 02 70 96 c4 fb')
# CWbytearray(b'ff 39 e8 51 2d 1f 64 2e 55 af 1f 02 70 96 c4 fb')
#
# text[0] avant,  98
# text avant,  CWbytearray(b'62 1a 11 4b 28 cf 85 64 47 5a aa d9 4e bb 9c 04')
# CWbytearray(b'00 1a 11 4b 28 cf 85 64 47 5a aa d9 4e bb 9c 04')
#
# text[0] avant,  41
# text avant,  CWbytearray(b'29 08 1e 0d ef e4 9f 47 f9 8f 57 b9 4e da 46 8f')
# CWbytearray(b'ff 08 1e 0d ef e4 9f 47 f9 8f 57 b9 4e da 46 8f')
#
# text[0] avant,  18
# text avant,  CWbytearray(b'12 77 55 4c 66 8b a3 3e 06 8e b4 86 66 db 6a dc')
# CWbytearray(b'00 77 55 4c 66 8b a3 3e 06 8e b4 86 66 db 6a dc')
#
# text[0] avant,  73
# text avant,  CWbytearray(b'49 35 96 bd 6e 22 5d e8 39 12 4c 8f a7 b7 56 8a')
# CWbytearray(b'ff 35 96 bd 6e 22 5d e8 39 12 4c 8f a7 b7 56 8a')
#
# text[0] avant,  32
# text avant,  CWbytearray(b'20 40 11 ed 73 05 b8 ec ed 0c 3f 8a 5d 52 d3 2d')
# CWbytearray(b'00 40 11 ed 73 05 b8 ec ed 0c 3f 8a 5d 52 d3 2d')
#
# text[0] avant,  255
# text avant,  CWbytearray(b'ff 87 34 0c 31 fe ec 20 28 fc c4 2f f7 19 bf fb')
# CWbytearray(b'ff 87 34 0c 31 fe ec 20 28 fc c4 2f f7 19 bf fb')
#
# text[0] avant,  58
# text avant,  CWbytearray(b'3a b2 7f 72 9a 64 27 94 2c 9b fc f7 6d e5 83 af')
# CWbytearray(b'00 b2 7f 72 9a 64 27 94 2c 9b fc f7 6d e5 83 af')
#
# text[0] avant,  140
# text avant,  CWbytearray(b'8c 10 3f cd fc 48 99 01 ff f3 3a 1d 98 2c d4 9a')
# CWbytearray(b'00 10 3f cd fc 48 99 01 ff f3 3a 1d 98 2c d4 9a')
#
# text[0] avant,  56
# text avant,  CWbytearray(b'38 45 ef 05 22 38 cc e3 8e 0f c1 70 26 ff b9 df')
# CWbytearray(b'00 45 ef 05 22 38 cc e3 8e 0f c1 70 26 ff b9 df')

# %%
assert len(trace_array) == 100
print("✔️ OK to continue!")
# Out:
# ✔️ OK to continue!

# %% [markdown]
# ## Grouping Traces
#
# As we've seen in the slides, we've made an assumption that setting bits on the data lines consumes a measurable amount of power. Now, we're going test that theory by getting our target to manipulate data with a very high Hamming weight (0xFF) and a very low Hamming weight (0x00). For this purpose, the target is currently running AES, and it encrypted the text we sent it. If we're correct in our assumption, we should see a measurable difference between power traces with a high Hamming weight and a low one.
#
# Currently, these traces are all mixed up. Separate them into two groups: `one_list` and `zero_list`. Here's an example of how we use the first byte to check for a 0x00, and assume if it's not that it's 0xFF. Here is a simple iteration to print them:

# %% [markdown]
# Now extend this to append them to two arrays, a `one_list` and a `zero_list`:

# %%
# ###################
# Let's remember that the message will go through a chiffrement process
# ###################

one_list = [] # list of traces where the first byte of the sent message is 0, really really a bad name
zero_list = [] # list of traces where the first byte of the sent message is 0

for i in range(len(trace_array)):
    if textin_array[i][0] == 0x00:
        one_list.append(trace_array[i])
    else:
        zero_list.append(trace_array[i])

print (len(one_list))
print (len(zero_list))

assert len(one_list) > len(zero_list)/2 # to know if it's balanced
assert len(zero_list) > len(one_list)/2
# Out:
# 54
# 46

# %% [markdown]
# We should have two different lists. Whether we sent 0xFF or 0x00 was random, so these lists likely won't be evenly dispersed. Next, we'll want to take an average of each group (make sure you take an average of each trace at each point! We don't want an average of the traces in time), which will help smooth out any outliers and also fix our issue of having a different number of traces for each group.
#
# The easiest way to accomplish this will be to use `np.mean()`, which can take a list as an argument. You'll need to specify the `axis` parameter as well, to ensure you take the correct dimension. Check the resulting size to make sure you still have traces of the same length as one input - the following block shows how you can verify that, assuming you used `one_avg` as the average.

# %%
trace_length = len(one_list[0])
print("Traces had original sample length of %d"%trace_length)

one_avg = np.mean(one_list, axis=0) # traces ou je sais que le 1er byte envoié est 0
zero_avg = np.mean(zero_list, axis=0) # traces ou je sais que le 1er byte envoié est 1

if len(one_avg) != trace_length:
    raise ValueError("Average length is only %d - check you did correct dimensions!"%one_avg)
# Out:
# Traces had original sample length of 5000

# %%
# I always like to compare traces without operation before
font = font_manager.FontProperties(style='normal', size=5)
plt.figure();
plt.xlabel('Simples')
plt.ylabel('Means of power cons')
plt.grid(True)
plt.title('Average Power Consumption \n message with first byte 0x11 vs 0x00')

plt.plot(zero_avg)
plt.plot(one_avg)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Finally, subtract the two averages and plot the resulting data:

# %%
font = font_manager.FontProperties(style='normal', size=5)
plt.figure();
plt.xlabel('Samples')
plt.ylabel('0x11.mean - 0x00.mean')
plt.grid(True)
plt.title('Subtraction of means \n')

resul_sub = np.abs(zero_avg - one_avg)  
plt.plot(resul_sub)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# You should see a very distinct trace near the beginning of the plot, meaning that the data being manipulated in the target device is visible in its power trace! Again, there's a lot of room to explore here:
#
# * Try setting multiple bytes to 0x00 and 0xFF.
# * Try using smaller hamming weight differences. Is the spike still distinct? What about if you capture more traces?
# * We focused on the first byte here. Try putting the difference plots for multiple different bytes on the same plot.
# * The target is running AES here. Can you get the spikes to appear in different places if you set a byte in a later round of AES (say round 5) to 0x00 or 0xFF?

# %% [markdown]
# ## [Simulated]

# %%
aes_traces_100_tracedata = np.load(r"traces/lab3_1_traces.npy")
aes_traces_100_textindata = np.load(r"traces/lab3_1_textin.npy")

trace_array = aes_traces_100_tracedata
textin_array = aes_traces_100_textindata

assert len(trace_array) == 100
print("✔️ OK to continue!")
# Out:
# ✔️ OK to continue!

# %% [markdown]
# - Definir bits nas linhas de dados consome uma quantidade mensurável de energia.
# - Fazer o alvo manipular dados com um peso de Hamming muito alto (0xFF) e muito baixo (0x00).
# - Para isso, o alvo está executando o AES no momento e criptografou o texto que enviamos.
# - Ver uma diferença mensurável entre traços de energia com um peso de Hamming alto e um baixo.
#
# Atualmente, esses traços estão todos misturados. Separe-os em dois grupos: one_list e zero_list. Aqui está um exemplo de como usamos o primeiro byte para verificar se há 0x00 e assumimos que, se não for, é 0xFF. Aqui está uma iteração simples para imprimi-los

# %%
print(trace_array.shape) # It means that trace_array has 100 subarrays and each one has 5000 samples
# Out:
# (100, 5000)

# %%
print(textin_array) # one message is a 16-position byte array
# Out:
# [[  0 176 161 ... 200 122 177]
#  [  0 219 190 ... 249 212 222]
#  [  0 198 153 ...  79  11  17]
#  ...
#  [  0 130  28 ...  46 114  45]
#  [  0 140  51 ... 179 132 147]
#  [  0 189 120 ...  71 108  85]]

# %% [markdown]
# Hamming weight goes from 00 to FF let's divide all these traces into 2 groups : one_list and zero_list

# %%
# ###################
# Let's remember that the message will go through a chiffrement process
# ###################

one_list = [] # list of traces where the first byte of the sent message is 0x00, really really a bad name
zero_list = [] # list of traces where the first byte of the sent message is 0xFF

for i in range(len(trace_array)):
    if textin_array[i][0] == 0x00:
        one_list.append(trace_array[i])
    else:
        zero_list.append(trace_array[i])

print (len(one_list))
print (len(zero_list))

assert len(one_list) > len(zero_list)/2 # to know if it's balanced
assert len(zero_list) > len(one_list)/2
# Out:
# 55
# 45

# %% [markdown]
# - Devemos ter duas listas diferentes.
# - Queremos obter uma média de cada grupo (uma média de cada traço em cada ponto! Não queremos uma média dos traços no tempo).
#
# axis : along which we want to calculate the arithmetic mean. Otherwise, it will consider arr to be flattened(works on all the axis).
# - axis = 0 means along the column
# - axis = 1 means working along the row

# %%
trace_length = len(one_list[0])
print("Traces had original sample length of %d"%trace_length)
one_avg = np.mean(one_list, axis=0) # traces ou je sais que le 1er byte envoié est 0

zero_avg = np.mean(zero_list, axis=0) # traces ou je sais que le 1er byte envoié est 1

if len(one_avg) != trace_length:
    raise ValueError("Average length is only %d - check you did correct dimensions!"%one_avg)
# Out:
# Traces had original sample length of 5000

# %%
font = font_manager.FontProperties(style='normal', size=5)
plt.figure();
plt.xlabel('Simples')
plt.ylabel('Means of power cons')
plt.grid(True)
plt.title('Average Power Consumption \nfirst byte 0x11 vs 0x00')

plt.plot(zero_avg)
plt.plot(one_avg)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Finally, subtract the two averages and plot the resulting data :

# %%
# here, I want to see the traces values in abs
font = font_manager.FontProperties(style='normal', size=5)
plt.figure();
plt.xlabel('Samples')
plt.ylabel('0x11.mean - 0x00.mean')
plt.grid(True)
plt.title('Subtraction of means \n')

resul_sub = np.abs(zero_avg - one_avg)  
plt.plot(resul_sub)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# You should see a very distinct trace near the beginning of the plot, meaning that the data being manipulated in the target device is visible in its power trace! Again, there's a lot of room to explore here:
#
# * Try setting multiple bytes to 0x00 and 0xFF.
# * Try using smaller hamming weight differences. Is the spike still distinct? What about if you capture more traces?
# * We focused on the first byte here. Try putting the difference plots for multiple different bytes on the same plot.
# * The target is running AES here. Can you get the spikes to appear in different places if you set a byte in a later round of AES (say round 5) to 0x00 or 0xFF?

# %% [markdown]
# ---
# <small>NO-FUN DISCLAIMER: This material is Copyright (C) NewAE Technology Inc., 2015-2020. ChipWhisperer is a trademark of NewAE Technology Inc., claimed in all jurisdictions, and registered in at least the United States of America, European Union, and Peoples Republic of China.
#
# Tutorials derived from our open-source work must be released under the associated open-source license, and notice of the source must be *clearly displayed*. Only original copyright holders may license or authorize other distribution - while NewAE Technology Inc. holds the copyright for many tutorials, the github repository includes community contributions which we cannot license under special terms and **must** be maintained as an open-source release. Please contact us for special permissions (where possible).
#
# THE SOFTWARE IS PROVIDED "AS IS", WITHOUT WARRANTY OF ANY KIND, EXPRESS OR IMPLIED, INCLUDING BUT NOT LIMITED TO THE WARRANTIES OF MERCHANTABILITY, FITNESS FOR A PARTICULAR PURPOSE AND NONINFRINGEMENT. IN NO EVENT SHALL THE AUTHORS OR COPYRIGHT HOLDERS BE LIABLE FOR ANY CLAIM, DAMAGES OR OTHER LIABILITY, WHETHER IN AN ACTION OF CONTRACT, TORT OR OTHERWISE, ARISING FROM, OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE SOFTWARE.</small>
